# %%
import os

root_dir = r"C:\Users\smoh\Desktop\26-1\Verilog\proj2\cur\try1"

for path, dirs, files in os.walk(root_dir):
    for file in files:
        if file.endswith(".txt") and not file.endswith("_try1.txt"):
            
            old_path = os.path.join(path, file)

            name, ext = os.path.splitext(file)
            new_file = f"{name}_try1{ext}"
            new_path = os.path.join(path, new_file)

            os.rename(old_path, new_path)

            print(f"{old_path} -> {new_path}")
# Out:
# C:\Users\smoh\Desktop\26-1\Verilog\proj2\cur\try1\DCT_image_1.txt -> C:\Users\smoh\Desktop\26-1\Verilog\proj2\cur\try1\DCT_image_1_try1.txt
# C:\Users\smoh\Desktop\26-1\Verilog\proj2\cur\try1\DCT_image_2.txt -> C:\Users\smoh\Desktop\26-1\Verilog\proj2\cur\try1\DCT_image_2_try1.txt
# C:\Users\smoh\Desktop\26-1\Verilog\proj2\cur\try1\DCT_image_3.txt -> C:\Users\smoh\Desktop\26-1\Verilog\proj2\cur\try1\DCT_image_3_try1.txt
# C:\Users\smoh\Desktop\26-1\Verilog\proj2\cur\try1\DCT_image_4.txt -> C:\Users\smoh\Desktop\26-1\Verilog\proj2\cur\try1\DCT_image_4_try1.txt
# C:\Users\smoh\Desktop\26-1\Verilog\proj2\cur\try1\DCT_image_5.txt -> C:\Users\smoh\Desktop\26-1\Verilog\proj2\cur\try1\DCT_image_5_try1.txt
# C:\Users\smoh\Desktop\26-1\Verilog\proj2\cur\try1\DCT_image_6.txt -> C:\Users\smoh\Desktop\26-1\Verilog\proj2\cur\try1\DCT_image_6_try1.txt
# C:\Users\smoh\Desktop\26-1\Verilog\proj2\cur\try1\DCT_image_7.txt -> C:\Users\smoh\Desktop\26-1\Verilog\proj2\cur\try1\DCT_image_7_try1.txt

# %%
with open(r"C:\Users\smoh\Desktop\26-1\Verilog\proj2\cur\result\try1\DCT_image_1_try1.txt", "rb") as f1, \
     open(r"C:\Users\smoh\Desktop\26-1\Verilog\proj2\ref\matlab\DCT_image_1.txt", "rb") as f2:

    data1 = f1.read()
    data2 = f2.read()

if data1 == data2:
    print("같음")
else:
    print("다름")
